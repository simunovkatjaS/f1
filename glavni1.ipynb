# %%
pip install fastf1 pandas matplotlib
# Out:
# Collecting fastf1
#   Downloading fastf1-3.8.3-py3-none-any.whl.metadata (5.1 kB)
# Requirement already satisfied: pandas in /usr/local/lib/python3.12/dist-packages (2.2.2)
# Requirement already satisfied: matplotlib in /usr/local/lib/python3.12/dist-packages (3.10.0)
# Requirement already satisfied: cryptography in /usr/local/lib/python3.12/dist-packages (from fastf1) (49.0.0)
# Requirement already satisfied: numpy<3.0.0,>=1.26.0 in /usr/local/lib/python3.12/dist-packages (from fastf1) (2.0.2)
# Requirement already satisfied: platformdirs in /usr/local/lib/python3.12/dist-packages (from fastf1) (4.10.0)
# Requirement already satisfied: pydantic in /usr/local/lib/python3.12/dist-packages (from fastf1) (2.13.4)
# Requirement already satisfied: pyjwt in /usr/local/lib/python3.12/dist-packages (from fastf1) (2.13.0)
# Requirement already satisfied: python-dateutil in /usr/local/lib/python3.12/dist-packages (from fastf1) (2.9.0.post0)
# Collecting rapidfuzz (from fastf1)
#   Downloading rapidfuzz-3.14.5-cp312-cp312-manylinux_2_27_x86_64.manylinux_2_28_x86_64.whl.metadata (12 kB)
# Collecting requests-cache>=1.0.0 (from fastf1)
#   Downloading requests_cache-1.3.3-py3-none-any.whl.metadata (9.4 kB)
# Requirement already satisfied: requests>=2.30.0 in /usr/local/lib/python3.12/dist-packages (from fastf1) (2.32.4)
# Requirement already satisfied: scipy<2.0.0,>=1.11.0 in /usr/local/lib/python3.12/dist-packages (from fastf1) (1.16.3)
# Collecting signalrcore (from fastf1)
#   Downloading signalrcore-1.0.2-py3-none-any.whl.metadata (13 kB)
# Collecting timple>=0.1.6 (from fastf1)
#   Downloading timple-0.1.8-py3-none-any.whl.metadata (2.0 kB)
# Requirement already satisfied: websockets>=10.3 in /usr/local/lib/python3.12/dist-packages (from fastf1) (15.0.1)
# Requirement already satisfied: pytz>=2020.1 in /usr/local/lib/python3.12/dist-packages (from pandas) (2025.2)
# Requirement already satisfied: tzdata>=2022.7 in /usr/local/lib/python3.12/dist-packages (from pandas) (2026.2)
# Requirement already satisfied: contourpy>=1.0.1 in /usr/local/lib/python3.12/dist-packages (from matplotlib) (1.3.3)
# Requirement already satisfied: cycler>=0.10 in /usr/local/lib/python3.12/dist-packages (from matplotlib) (0.12.1)
# Requirement already satisfied: fonttools>=4.22.0 in /usr/local/lib/python3.12/dist-packages (from matplotlib) (4.63.0)
# Requirement already satisfied: kiwisolver>=1.3.1 in /usr/local/lib/python3.12/dist-packages (from matplotlib) (1.5.0)
# Requirement already satisfied: packaging>=20.0 in /usr/local/lib/python3.12/dist-packages (from matplotlib) (26.2)
# Requirement already satisfied: pillow>=8 in /usr/local/lib/python3.12/dist-packages (from matplotlib) (11.3.0)
# Requirement already satisfied: pyparsing>=2.3.1 in /usr/local/lib/python3.12/dist-packages (from matplotlib) (3.3.2)
# Requirement already satisfied: six>=1.5 in /usr/local/lib/python3.12/dist-packages (from python-dateutil->fastf1) (1.17.0)
# Requirement already satisfied: charset_normalizer<4,>=2 in /usr/local/lib/python3.12/dist-packages (from requests>=2.30.0->fastf1) (3.4.7)
# Requirement already satisfied: idna<4,>=2.5 in /usr/local/lib/python3.12/dist-packages (from requests>=2.30.0->fastf1) (3.18)
# Requirement already satisfied: urllib3<3,>=1.21.1 in /usr/local/lib/python3.12/dist-packages (from requests>=2.30.0->fastf1) (2.5.0)
# Requirement already satisfied: certifi>=2017.4.17 in /usr/local/lib/python3.12/dist-packages (from requests>=2.30.0->fastf1) (2026.6.17)
# Requirement already satisfied: attrs>=21.2 in /usr/local/lib/python3.12/dist-packages (from requests-cache>=1.0.0->fastf1) (26.1.0)
# Collecting cattrs>=22.2 (from requests-cache>=1.0.0->fastf1)
#   Downloading cattrs-26.1.0-py3-none-any.whl.metadata (8.5 kB)
# Collecting url-normalize>=2.0 (from requests-cache>=1.0.0->fastf1)
#   Downloading url_normalize-3.0.0-py3-none-any.whl.metadata (7.5 kB)
# Requirement already satisfied: cffi>=2.0.0 in /usr/local/lib/python3.12/dist-packages (from cryptography->fastf1) (2.0.0)
# Requirement already satisfied: annotated-types>=0.6.0 in /usr/local/lib/python3.12/dist-packages (from pydantic->fastf1) (0.7.0)
# Requirement already satisfied: pydantic-core==2.46.4 in /usr/local/lib/python3.12/dist-packages (from pydantic->fastf1) (2.46.4)
# Requirement already satisfied: typing-extensions>=4.14.1 in /usr/local/lib/python3.12/dist-packages (from pydantic->fastf1) (4.15.0)
# Requirement already satisfied: typing-inspection>=0.4.2 in /usr/local/lib/python3.12/dist-packages (from pydantic->fastf1) (0.4.2)
# Collecting msgpack==1.1.2 (from signalrcore->fastf1)
#   Downloading msgpack-1.1.2-cp312-cp312-manylinux2014_x86_64.manylinux_2_17_x86_64.manylinux_2_28_x86_64.whl.metadata (8.1 kB)
# Requirement already satisfied: pycparser in /usr/local/lib/python3.12/dist-packages (from cffi>=2.0.0->cryptography->fastf1) (3.0)
# Downloading fastf1-3.8.3-py3-none-any.whl (135 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 136.0/136.0 kB 15.6 MB/s eta 0:00:00
# Downloading requests_cache-1.3.3-py3-none-any.whl (70 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 70.8/70.8 kB 8.1 MB/s eta 0:00:00
# Downloading timple-0.1.8-py3-none-any.whl (17 kB)
# Downloading rapidfuzz-3.14.5-cp312-cp312-manylinux_2_27_x86_64.manylinux_2_28_x86_64.whl (3.1 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 3.1/3.1 MB 105.5 MB/s eta 0:00:00
# Downloading signalrcore-1.0.2-py3-none-any.whl (55 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 55.6/55.6 kB 6.3 MB/s eta 0:00:00
# Downloading msgpack-1.1.2-cp312-cp312-manylinux2014_x86_64.manylinux_2_17_x86_64.manylinux_2_28_x86_64.whl (427 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 427.6/427.6 kB 42.3 MB/s eta 0:00:00
# Downloading cattrs-26.1.0-py3-none-any.whl (73 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 73.1/73.1 kB 8.5 MB/s eta 0:00:00
# Downloading url_normalize-3.0.0-py3-none-any.whl (16 kB)
# Installing collected packages: url-normalize, rapidfuzz, msgpack, cattrs, signalrcore, requests-cache, timple, fastf1
#   Attempting uninstall: msgpack
#     Found existing installation: msgpack 1.2.1
#     Uninstalling msgpack-1.2.1:
#       Successfully uninstalled msgpack-1.2.1
# Successfully installed cattrs-26.1.0 fastf1-3.8.3 msgpack-1.1.2 rapidfuzz-3.14.5 requests-cache-1.3.3 signalrcore-1.0.2 timple-0.1.8 url-normalize-3.0.0

# %%
import fastf1
from google.colab import drive
drive.mount('/content/drive')

import os
cache_path = '/content/drive/MyDrive/f1_cache'
os.makedirs(cache_path, exist_ok=True)

fastf1.Cache.enable_cache(cache_path)
# Out:
# Mounted at /content/drive

# %%
session = fastf1.get_session(2025, 'Singapore', 'R')
session.load()

print(session.results[['Abbreviation', 'TeamName', 'Position']])
# Out:
# core           INFO 	Loading data for Singapore Grand Prix - Race [v3.8.3]
# INFO:fastf1.fastf1.core:Loading data for Singapore Grand Prix - Race [v3.8.3]
# req            INFO 	No cached data found for session_info. Loading data...
# INFO:fastf1.fastf1.req:No cached data found for session_info. Loading data...
# _api           INFO 	Fetching session info data...
# INFO:fastf1.api:Fetching session info data...
# DEBUG:fastf1.api:Falling back to livetiming mirror (https://livetiming-mirror.fastf1.dev)
# logger      WARNING 	Failed to load session info data!
# WARNING:fastf1.fastf1.core:Failed to load session info data!
# DEBUG:fastf1.fastf1.core:Traceback for failure in session info data
# Traceback (most recent call last):
#   File "/usr/local/lib/python3.12/dist-packages/fastf1/logger.py", line 112, in __wrapped
#     return func(*args, **kwargs)
#            ^^^^^^^^^^^^^^^^^^^^^
#   File "/usr/local/lib/python3.12/dist-packages/fastf1/core.py", line 1452, in _load_session_info
#     self._session_info = api.session_info(self.api_path,
#                          ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "/usr/local/lib/python3.12/dist-packages/fastf1/req.py", line 459, in _cached_api_request
#     data = func(api_path, **func_kwargs)
#            ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "/usr/local/lib/python3.12/dist-packages/fastf1/_api.py", line 1730, in session_info
#     raise SessionNotAvailableError(
# fastf1._api.SessionNotAvailableError: No data for this session! If this session only finished recently, please try again in a few minutes.
# req            INFO 	No cached data found for driver_info. Loading data...
# INFO:fastf1.fastf1.req:No cached data found for driver_info. Loading data...
# _api           INFO 	Fetching driver list...
# INFO:fastf1.api:Fetching driver list...
# DEBUG:fastf1.api:Falling back to livetiming mirror (https://livetiming-mirror.fastf1.dev)
# core        WARNING 	Failed to load extended driver information!
# WARNING:fastf1.fastf1.core:Failed to load extended driver information!
# DEBUG:fastf1.fastf1.core:Exception while loading driver list
# Traceback (most recent call last):
#   File "/usr/local/lib/python3.12/dist-packages/fastf1/core.py", line 2459, in _drivers_from_f1_api
#     f1di = api.driver_info(self.api_path, livedata=livedata)
#            ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "/usr/local/lib/python3.12/dist-packages/fastf1/req.py", line 459, in _cached_api_request
#     data = func(api_path, **func_kwargs)
#            ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "/usr/local/lib/python3.12/dist-packages/fastf1/_api.py", line 1564, in driver_info
#     raise SessionNotAvailableError(
# fastf1._api.SessionNotAvailableError: No data for this session! If this session only finished recently, please try again in a few minutes.
# req            INFO 	No cached data found for session_status_data. Loading data...
# INFO:fastf1.fastf1.req:No cached data found for session_status_data. Loading data...
# _api           INFO 	Fetching session status data...
# INFO:fastf1.api:Fetching session status data...
# DEBUG:fastf1.api:Falling back to livetiming mirror (https://livetiming-mirror.fastf1.dev)
# logger      WARNING 	Failed to load session status data!
# WARNING:fastf1.fastf1.core:Failed to load session status data!
# DEBUG:fastf1.fastf1.core:Traceback for failure in session status data
# Traceback (most recent call last):
#   File "/usr/local/lib/python3.12/dist-packages/fastf1/logger.py", line 112, in __wrapped
#     return func(*args, **kwargs)
#            ^^^^^^^^^^^^^^^^^^^^^
#   File "/usr/local/lib/python3.12/dist-packages/fastf1/core.py", line 2136, in _load_session_status_data
#     session_status = api.session_status_data(self.api_path,
#                      ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "/usr/local/lib/python3.12/dist-packages/fastf1/req.py", line 459, in _cached_api_request
#     data = func(api_path, **func_kwargs)
#            ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "/usr/local/lib/python3.12/dist-packages/fastf1/_api.py", line 1362, in session_status_data
#     raise SessionNotAvailableError(
# fastf1._api.SessionNotAvailableError: No data for this session! If this session only finished recently, please try again in a few minutes.
# req            INFO 	No cached data found for lap_count. Loading data...
# INFO:fastf1.fastf1.req:No cached data found for lap_count. Loading data...
# _api           INFO 	Fetching lap count data...
# INFO:fastf1.api:Fetching lap count data...
# DEBUG:fastf1.api:Falling back to livetiming mirror (https://livetiming-mirror.fastf1.dev)
# logger      WARNING 	Failed to load total lap count!
# WARNING:fastf1.fastf1.core:Failed to load total lap count!
# DEBUG:fastf1.fastf1.core:Traceback for failure in total lap count
# Traceback (most recent call last):
#   File "/usr/local/lib/python3.12/dist-packages/fastf1/logger.py", line 112, in __wrapped
#     return func(*args, **kwargs)
#            ^^^^^^^^^^^^^^^^^^^^^
#   File "/usr/local/lib/python3.12/dist-packages/fastf1/core.py", line 2118, in _load_total_lap_count
#     lap_count = api.lap_count(self.api_path, livedata=livedata)
#                 ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "/usr/local/lib/python3.12/dist-packages/fastf1/req.py", line 459, in _cached_api_request
#     data = func(api_path, **func_kwargs)
#            ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "/usr/local/lib/python3.12/dist-packages/fastf1/_api.py", line 1505, in lap_count
#     raise SessionNotAvailableError(
# fastf1._api.SessionNotAvailableError: No data for this session! If this session only finished recently, please try again in a few minutes.
# req            INFO 	No cached data found for track_status_data. Loading data...
# INFO:fastf1.fastf1.req:No cached data found for track_status_data. Loading data...
# _api           INFO 	Fetching track status data...
# INFO:fastf1.api:Fetching track status data...
# DEBUG:fastf1.api:Falling back to livetiming mirror (https://livetiming-mirror.fastf1.dev)
# logger      WARNING 	Failed to load track status data!
# WARNING:fastf1.fastf1.core:Failed to load track status data!
# DEBUG:fastf1.fastf1.core:Traceback for failure in track status data
# Traceback (most recent call last):
#   File "/usr/local/lib/python3.12/dist-packages/fastf1/logger.py", line 112, in __wrapped
#     return func(*args, **kwargs)
#            ^^^^^^^^^^^^^^^^^^^^^
#   File "/usr/local/lib/python3.12/dist-packages/fastf1/core.py", line 2105, in _load_track_status_data
#     track_status = api.track_status_data(self.api_path, livedata=livedata)
#                    ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "/usr/local/lib/python3.12/dist-packages/fastf1/req.py", line 459, in _cached_api_request
#     data = func(api_path, **func_kwargs)
#            ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "/usr/local/lib/python3.12/dist-packages/fastf1/_api.py", line 1306, in track_status_data
#     raise SessionNotAvailableError(
# fastf1._api.SessionNotAvailableError: No data for this session! If this session only finished recently, please try again in a few minutes.
# req            INFO 	No cached data found for _extended_timing_data. Loading data...
# INFO:fastf1.fastf1.req:No cached data found for _extended_timing_data. Loading data...
# _api           INFO 	Fetching timing data...
# INFO:fastf1.api:Fetching timing data...
# DEBUG:fastf1.api:Falling back to livetiming mirror (https://livetiming-mirror.fastf1.dev)
# logger      WARNING 	Failed to load timing data!
# WARNING:fastf1.fastf1.core:Failed to load timing data!
# DEBUG:fastf1.fastf1.core:Traceback for failure in lap timing data
# Traceback (most recent call last):
#   File "/usr/local/lib/python3.12/dist-packages/fastf1/logger.py", line 112, in __wrapped
#     return func(*args, **kwargs)
#            ^^^^^^^^^^^^^^^^^^^^^
#   File "/usr/local/lib/python3.12/dist-packages/fastf1/core.py", line 1458, in _load_laps_data
#     = api._extended_timing_data(self.api_path, livedata=livedata)
#       ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "/usr/local/lib/python3.12/dist-packages/fastf1/req.py", line 459, in _cached_api_request
#     data = func(api_path, **func_kwargs)
#            ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "/usr/local/lib/python3.12/dist-packages/fastf1/_api.py", line 201, in _extended_timing_data
#     raise SessionNotAvailableError(
# fastf1._api.SessionNotAvailableError: No data for this session! If this session only finished recently, please try again in a few minutes.
# DEBUG:fastf1.fastf1.core:Failed to add first lap time for driver '63'
# Traceback (most recent call last):
#   File "/usr/local/lib/python3.12/dist-packages/fastf1/core.py", line 2088, in _add_first_lap_time_from_ergast
#     self._laps.loc[
#     ^^^^^^^^^^
# AttributeError: 'Session' object has no attribute '_laps'. Did you mean: 'laps'?
# DEBUG:fastf1.fastf1.core:Failed to add first lap time for driver '1'
# Traceback (most recent call last):
#   File "/usr/local/lib/python3.12/dist-packages/fastf1/core.py", line 2088, in _add_first_lap_time_from_ergast
#     self._laps.loc[
#     ^^^^^^^^^^
# AttributeError: 'Session' object has no attribute '_laps'. Did you mean: 'laps'?
# DEBUG:fastf1.fastf1.core:Failed to add first lap time for driver '4'
# Traceback (most recent call last):
#   File "/usr/local/lib/python3.12/dist-packages/fastf1/core.py", line 2088, in _add_first_lap_time_from_ergast
#     self._laps.loc[
#     ^^^^^^^^^^
# AttributeError: 'Session' object has no attribute '_laps'. Did you mean: 'laps'?
# DEBUG:fastf1.fastf1.core:Failed to add first lap time for driver '81'
# Traceback (most recent call last):
#   File "/usr/local/lib/python3.12/dist-packages/fastf1/core.py", line 2088, in _add_first_lap_time_from_ergast
#     self._laps.loc[
#     ^^^^^^^^^^
# AttributeError: 'Session' object has no attribute '_laps'. Did you mean: 'laps'?
# DEBUG:fastf1.fastf1.core:Failed to add first lap time for driver '16'
# Traceback (most recent call last):
#   File "/usr/local/lib/python3.12/dist-packages/fastf1/core.py", line 2088, in _add_first_lap_time_from_ergast
#     self._laps.loc[
#     ^^^^^^^^^^
# AttributeError: 'Session' object has no attribute '_laps'. Did you mean: 'laps'?
# DEBUG:fastf1.fastf1.core:Failed to add first lap time for driver '12'
# Traceback (most recent call last):
#   File "/usr/local/lib/python3.12/dist-packages/fastf1/core.py", line 2088, in _add_first_lap_time_from_ergast
#     self._laps.loc[
#     ^^^^^^^^^^
# AttributeError: 'Session' object has no attribute '_laps'. Did you mean: 'laps'?
# DEBUG:fastf1.fastf1.core:Failed to add first lap time for driver '44'
# Traceback (most recent call last):
#   File "/usr/local/lib/python3.12/dist-packages/fastf1/core.py", line 2088, in _add_first_lap_time_from_ergast
#     self._laps.loc[
#     ^^^^^^^^^^
# AttributeError: 'Session' object has no attribute '_laps'. Did you mean: 'laps'?
# DEBUG:fastf1.fastf1.core:Failed to add first lap time for driver '6'
# Traceback (most recent call last):
#   File "/usr/local/lib/python3.12/dist-packages/fastf1/core.py", line 2088, in _add_first_lap_time_from_ergast
#     self._laps.loc[
#     ^^^^^^^^^^
# AttributeError: 'Session' object has no attribute '_laps'. Did you mean: 'laps'?
# DEBUG:fastf1.fastf1.core:Failed to add first lap time for driver '14'
# Traceback (most recent call last):
#   File "/usr/local/lib/python3.12/dist-packages/fastf1/core.py", line 2088, in _add_first_lap_time_from_ergast
#     self._laps.loc[
#     ^^^^^^^^^^
# AttributeError: 'Session' object has no attribute '_laps'. Did you mean: 'laps'?
# DEBUG:fastf1.fastf1.core:Failed to add first lap time for driver '87'
# Traceback (most recent call last):
#   File "/usr/local/lib/python3.12/dist-packages/fastf1/core.py", line 2088, in _add_first_lap_time_from_ergast
#     self._laps.loc[
#     ^^^^^^^^^^
# AttributeError: 'Session' object has no attribute '_laps'. Did you mean: 'laps'?
# DEBUG:fastf1.fastf1.core:Failed to add first lap time for driver '27'
# Traceback (most recent call last):
#   File "/usr/local/lib/python3.12/dist-packages/fastf1/core.py", line 2088, in _add_first_lap_time_from_ergast
#     self._laps.loc[
#     ^^^^^^^^^^
# AttributeError: 'Session' object has no attribute '_laps'. Did you mean: 'laps'?
# DEBUG:fastf1.fastf1.core:Failed to add first lap time for driver '30'
# Traceback (most recent call last):
#   File "/usr/local/lib/python3.12/dist-packages/fastf1/core.py", line 2088, in _add_first_lap_time_from_ergast
#     self._laps.loc[
#     ^^^^^^^^^^
# AttributeError: 'Session' object has no attribute '_laps'. Did you mean: 'laps'?
# DEBUG:fastf1.fastf1.core:Failed to add first lap time for driver '43'
# Traceback (most recent call last):
#   File "/usr/local/lib/python3.12/dist-packages/fastf1/core.py", line 2088, in _add_first_lap_time_from_ergast
#     self._laps.loc[
#     ^^^^^^^^^^
# AttributeError: 'Session' object has no attribute '_laps'. Did you mean: 'laps'?
# DEBUG:fastf1.fastf1.core:Failed to add first lap time for driver '18'
# Traceback (most recent call last):
#   File "/usr/local/lib/python3.12/dist-packages/fastf1/core.py", line 2088, in _add_first_lap_time_from_ergast
#     self._laps.loc[
#     ^^^^^^^^^^
# AttributeError: 'Session' object has no attribute '_laps'. Did you mean: 'laps'?
# DEBUG:fastf1.fastf1.core:Failed to add first lap time for driver '5'
# Traceback (most recent call last):
#   File "/usr/local/lib/python3.12/dist-packages/fastf1/core.py", line 2088, in _add_first_lap_time_from_ergast
#     self._laps.loc[
#     ^^^^^^^^^^
# AttributeError: 'Session' object has no attribute '_laps'. Did you mean: 'laps'?
# DEBUG:fastf1.fastf1.core:Failed to add first lap time for driver '22'
# Traceback (most recent call last):
#   File "/usr/local/lib/python3.12/dist-packages/fastf1/core.py", line 2088, in _add_first_lap_time_from_ergast
#     self._laps.loc[
#     ^^^^^^^^^^
# AttributeError: 'Session' object has no attribute '_laps'. Did you mean: 'laps'?
# DEBUG:fastf1.fastf1.core:Failed to add first lap time for driver '31'
# Traceback (most recent call last):
#   File "/usr/local/lib/python3.12/dist-packages/fastf1/core.py", line 2088, in _add_first_lap_time_from_ergast
#     self._laps.loc[
#     ^^^^^^^^^^
# AttributeError: 'Session' object has no attribute '_laps'. Did you mean: 'laps'?
# DEBUG:fastf1.fastf1.core:Failed to add first lap time for driver '55'
# Traceback (most recent call last):
#   File "/usr/local/lib/python3.12/dist-packages/fastf1/core.py", line 2088, in _add_first_lap_time_from_ergast
#     self._laps.loc[
#     ^^^^^^^^^^
# AttributeError: 'Session' object has no attribute '_laps'. Did you mean: 'laps'?
# DEBUG:fastf1.fastf1.core:Failed to add first lap time for driver '10'
# Traceback (most recent call last):
#   File "/usr/local/lib/python3.12/dist-packages/fastf1/core.py", line 2088, in _add_first_lap_time_from_ergast
#     self._laps.loc[
#     ^^^^^^^^^^
# AttributeError: 'Session' object has no attribute '_laps'. Did you mean: 'laps'?
# DEBUG:fastf1.fastf1.core:Failed to add first lap time for driver '23'
# Traceback (most recent call last):
#   File "/usr/local/lib/python3.12/dist-packages/fastf1/core.py", line 2088, in _add_first_lap_time_from_ergast
#     self._laps.loc[
#     ^^^^^^^^^^
# AttributeError: 'Session' object has no attribute '_laps'. Did you mean: 'laps'?
# core        WARNING 	Failed to add first lap time from Ergast for drivers: ['63', '1', '4', '81', '16', '12', '44', '6', '14', '87', '27', '30', '43', '18', '5', '22', '31', '55', '10', '23']
# WARNING:fastf1.fastf1.core:Failed to add first lap time from Ergast for drivers: ['63', '1', '4', '81', '16', '12', '44', '6', '14', '87', '27', '30', '43', '18', '5', '22', '31', '55', '10', '23']
# req            INFO 	No cached data found for car_data. Loading data...
# INFO:fastf1.fastf1.req:No cached data found for car_data. Loading data...
# _api           INFO 	Fetching car data...
# INFO:fastf1.api:Fetching car data...
# DEBUG:fastf1.api:Falling back to livetiming mirror (https://livetiming-mirror.fastf1.dev)
# core        WARNING 	Car telemetry data is unavailable!
# WARNING:fastf1.fastf1.core:Car telemetry data is unavailable!
# req            INFO 	No cached data found for position_data. Loading data...
# INFO:fastf1.fastf1.req:No cached data found for position_data. Loading data...
# _api           INFO 	Fetching position data...
# INFO:fastf1.api:Fetching position data...
# DEBUG:fastf1.api:Falling back to livetiming mirror (https://livetiming-mirror.fastf1.dev)
# core        WARNING 	Car position data is unavailable!
# WARNING:fastf1.fastf1.core:Car position data is unavailable!
# core        WARNING 	Failed to determine `Session.t0_date`!
# WARNING:fastf1.fastf1.core:Failed to determine `Session.t0_date`!
# req            INFO 	No cached data found for weather_data. Loading data...
# INFO:fastf1.fastf1.req:No cached data found for weather_data. Loading data...
# _api           INFO 	Fetching weather data...
# INFO:fastf1.api:Fetching weather data...
# DEBUG:fastf1.api:Falling back to livetiming mirror (https://livetiming-mirror.fastf1.dev)
# logger      WARNING 	Failed to load weather data!
# WARNING:fastf1.fastf1.core:Failed to load weather data!
# DEBUG:fastf1.fastf1.core:Traceback for failure in weather data
# Traceback (most recent call last):
#   File "/usr/local/lib/python3.12/dist-packages/fastf1/logger.py", line 112, in __wrapped
#     return func(*args, **kwargs)
#            ^^^^^^^^^^^^^^^^^^^^^
#   File "/usr/local/lib/python3.12/dist-packages/fastf1/core.py", line 2611, in _load_weather_data
#     weather_data = api.weather_data(self.api_path, livedata=livedata)
#                    ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "/usr/local/lib/python3.12/dist-packages/fastf1/req.py", line 459, in _cached_api_request
#     data = func(api_path, **func_kwargs)
#            ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "/usr/local/lib/python3.12/dist-packages/fastf1/_api.py", line 1656, in weather_data
#     raise SessionNotAvailableError(
# fastf1._api.SessionNotAvailableError: No data for this session! If this session only finished recently, please try again in a few minutes.
# req            INFO 	No cached data found for race_control_messages. Loading data...
# INFO:fastf1.fastf1.req:No cached data found for race_control_messages. Loading data...
# _api           INFO 	Fetching race control messages...
# INFO:fastf1.api:Fetching race control messages...
# DEBUG:fastf1.api:Falling back to livetiming mirror (https://livetiming-mirror.fastf1.dev)
# logger      WARNING 	Failed to load race control messages!
# WARNING:fastf1.fastf1.core:Failed to load race control messages!
# DEBUG:fastf1.fastf1.core:Traceback for failure in race control messages
# Traceback (most recent call last):
#   File "/usr/local/lib/python3.12/dist-packages/fastf1/logger.py", line 112, in __wrapped
#     return func(*args, **kwargs)
#            ^^^^^^^^^^^^^^^^^^^^^
#   File "/usr/local/lib/python3.12/dist-packages/fastf1/core.py", line 2618, in _load_race_control_messages
#     race_control_messages = api.race_control_messages(self.api_path,
#                             ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "/usr/local/lib/python3.12/dist-packages/fastf1/req.py", line 459, in _cached_api_request
#     data = func(api_path, **func_kwargs)
#            ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "/usr/local/lib/python3.12/dist-packages/fastf1/_api.py", line 1433, in race_control_messages
#     raise SessionNotAvailableError(
# fastf1._api.SessionNotAvailableError: No data for this session! If this session only finished recently, please try again in a few minutes.
# core           INFO 	Finished loading data for 20 drivers: ['63', '1', '4', '81', '12', '16', '14', '44', '87', '55', '6', '22', '18', '23', '30', '43', '5', '31', '10', '27']
# INFO:fastf1.fastf1.core:Finished loading data for 20 drivers: ['63', '1', '4', '81', '12', '16', '14', '44', '87', '55', '6', '22', '18', '23', '30', '43', '5', '31', '10', '27']
#              Abbreviation        TeamName  Position
# DriverNumber
# 63                    RUS        Mercedes       1.0
# 1                     VER        Red Bull       2.0
# 4                     NOR         McLaren       3.0
# 81                    PIA         McLaren       4.0
# 12                    ANT        Mercedes       5.0
# 16                    LEC         Ferrari       6.0
# 14                    ALO    Aston Martin       7.0
# 44                    HAM         Ferrari       8.0
# 87                    BEA    Haas F1 Team       9.0
# 55                    SAI        Williams      10.0
# 6                     HAD      RB F1 Team      11.0
# 22                    TSU        Red Bull      12.0
# 18                    STR    Aston Martin      13.0
# 23                    ALB        Williams      14.0
# 30                    LAW      RB F1 Team      15.0
# 43                    COL  Alpine F1 Team      16.0
# 5                     BOR          Sauber      17.0
# 31                    OCO    Haas F1 Team      18.0
# 10                    GAS  Alpine F1 Team      19.0
# 27                    HUL          Sauber      20.0
